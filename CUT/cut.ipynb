# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/CUT')

# %%
# !pip install -r requirements.txt

# %%
# !nvidia-smi
# Out:
# Thu Nov 25 16:49:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   50C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
files = os.listdir('/content/drive/MyDrive/test')

# %%
print(len(files))
# Out:
# 12288

# %%
# !python train.py --dataroot /content/drive/MyDrive/train --name base20211125 --CUT_mode CUT --use_wandb --continue_train --dataset_mode aligned

# %%
# !python train.py --dataroot /content/drive/MyDrive/data_AB --name black2black1115 --CUT_mode CUT --use_wandb --continue_train --dataset_mode aligned

# %%
# !python checkmodel.py
